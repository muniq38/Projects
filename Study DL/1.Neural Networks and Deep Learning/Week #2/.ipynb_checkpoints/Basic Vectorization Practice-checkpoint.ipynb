# %%
import numpy as np

a = np.array([1,2,3,4])
print(a)
# Out:
# [1 2 3 4]

# %%
import time

a = np.random.rand(1000000)
b = np.random.rand(1000000)

tic = time.time()
c = np.dot(a,b)
toc = time.time()

print(c)
print("Vectorized Version:" + str(1000*(toc-tic)) + "ms")

c = 0
tic = time.time()
for i in range(1000000):
    c += a[i]*b[i]
toc = time.time()

print(c)
print("ForLoop Version:" + str(1000*(toc-tic)) + "ms")
# Out:
# 250037.58848965907
# Vectorized Version:0.9980201721191406ms
# 250037.5884896645
# ForLoop Version:484.50541496276855ms
